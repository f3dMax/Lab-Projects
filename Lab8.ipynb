# %% [markdown]
# # Lab 8 - File I/O and Frankenstein
# ### Name: Maksym Fedenko
#
# This lab is designed to give you practice with file I/O and to give you a chance to work with a larger program.  You will be writing a program that will read in a text file and then create a new file that is a modified version of the original.  The program will then read in the modified file and print out some statistics about the file.

# %%
# Take in the Frankenstein text using open and read
# Open the file
with open('frankenstein.txt', 'r', encoding='utf-8') as file:
    text = file.read()

# %%
# Show the start of the file (first 1000 characters)
# Note: Use slicing to get the first 1000 characters
test = text[:1000]

print (test)
# Out:
# The Project Gutenberg eBook of Frankenstein; Or, The Modern Prometheus
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.
#
# Title: Frankenstein; Or, The Modern Prometheus
#
#
# Author: Mary Wollstonecraft Shelley
#
# Release date: October 1, 1993 [eBook #84]
#                 Most recently updated: December 2, 2022
#
# Language: English
#
# Credits: Judith Boss, Christy Phillips, Lynn Hanninen and David Meltzer. HTML version by Al Haines.
#         Further corrections by Menno de Leeuw.
#
#
# *** START OF THE PROJECT GUTENBERG EBOOK FRANKENSTEIN; OR, THE MODERN PROMETHEUS ***
#
#
#
# Frankenstein;
#
# or, the Modern Prometheu

# %%
# Show the end of the file (last 1000 characters)
# Note: Use slicing to get the last 1000 characters
#  H  E  L  L  O
#  0  1  2  3  4
# -5 -4 -3 -2 -1
tail = text[-1000:]
print (tail)
# Out:
# visit: www.gutenberg.org/donate.
#
# Section 5. General Information About Project Gutenberg™ electronic works
#
# Professor Michael S. Hart was the originator of the Project
# Gutenberg™ concept of a library of electronic works that could be
# freely shared with anyone. For forty years, he produced and
# distributed Project Gutenberg™ eBooks with only a loose network of
# volunteer support.
#
# Project Gutenberg™ eBooks are often created from several printed
# editions, all of which are confirmed as not protected by copyright in
# the U.S. unless a copyright notice is included. Thus, we do not
# necessarily keep eBooks in compliance with any particular paper
# edition.
#
# Most people start at our website which has the main PG search
# facility: www.gutenberg.org.
#
# This website includes information about Project Gutenberg™,
# including how to make donations to the Project Gutenberg Literary
# Archive Foundation, how to help produce our new eBooks, and how to
# subscribe to our email newsletter to hear about new eBooks.

# %%
# Notice there is a lot of extra stuff at the beginning and end of the file (The header and footer)
# Lets remove the header and footer
# Create a method called remove_gutenberg_header_footer that takes in a string and returns a string
# The method should remove the header and footer from the string
# The method should return the string with the header and footer removed
# Note: The header and footer are the same for all Gutenberg texts
# Note: The header and footer are marked by the following strings:
# *** START OF THE PROJECT GUTENBERG EBOOK FRANKENSTEIN; OR, THE MODERN PROMETHEUS ***
# *** END OF THE PROJECT GUTENBERG EBOOK FRANKENSTEIN; OR, THE MODERN PROMETHEUS ***



def remove_gutenberg_header_footer(text):
    start = text.find('*** START OF THE PROJECT GUTENBERG EBOOK FRANKENSTEIN; OR, THE MODERN PROMETHEUS ***')
    end = text.find('*** END OF THE PROJECT GUTENBERG EBOOK FRANKENSTEIN; OR, THE MODERN PROMETHEUS ***')
    
    return text[start:end]



# Call the remove_gutenberg_header_footer method with the text and save the result to a variable called text
fixed_text = remove_gutenberg_header_footer(text)

# %%
# Data Analysis
# Now that we have the text, lets do some analysis
# How many chapters are in the text?
# Note: Each chapter starts with the text "Chapter" and then a number
# Note: Use the count method to count the number of chapters but only in the first 1000 characters of the text
# Note: There are 24 chapters 
# Note: Use slicing to get the first 1000 characters
print(fixed_text[:1000].count('Chapter'))

# Try to remove punctuation
# Note: Use the replace method to replace punctuation with nothing
# Note: Use the lower method to make the text lowercase
# Note: Use the split method to split the text into words
# remember methods can be chained together like this: text.replace().replace().replace().lower().split()
words_cleaned = fixed_text.replace(',', '').replace('.', '').replace(';', '').replace(':', '').replace('?', '').replace('!', '').replace('"', '').replace('(', '').replace(')', '').lower().split()

# How many unique words are in the text?
# A unique word is a word that only appears once in the text
# Note: Use the set method to get the unique words
# Note: Use the len method to get the number of unique words
unique_words = set(words)
print(len(unique_words))
print (unique_words)

unique_words_cleaned = set(words_cleaned)
print("Cleaned Words Length: ", len(unique_words_cleaned))
print (unique_words_cleaned)
# How many times does the word "monster" appear in the text?
# Note: Use the count method to count the number of times "monster" appears in the text
print(fixed_text.count('monster'))
print(fixed_text.split().count('monster'))
# Out:
# 24
# 11608
# {'perform;', 'infinity', 'childish', 'incoherent', 'limit', 'acquit', 'well.', 'yield', 'command.', 'bier.', 'tinged', 'feel?', 'relative', 'Through', 'welfare', 'toils.', 'fifteen', 'lightning,', 'inexorable', 'conformation', 'ceremony', 'benefactor?', 'homeward', 'detestation', 'profane', 'wondrously', 'void', 'letter', 'exchanged', 'rooms,', 'sight', 'utterance,', 'dried', 'dismay.', 'path,', 'enjoyments', 'spoke;', 'retain', 'chances', 'Vicar', '“Ah!', 'countenance;', 'regret', 'harden', 'fact', 'frowns', 'bad', '“Man,”', 'ceased;', 'labour', 'frightful;', 'adversary', 'services', 'globe;', 'earnestness', 'implores', 'early,', 'residence,', 'waiting', 'Ireland', 'loudness', 'reflection', 'someone,', 'wandering', 'ample,', 'write!', 'proposed', 'kind', 'arisen', '_in', '5th,', '‘Pardon', 'infirmities.', 'indignant', 'Oh,', 'wishes', 'presence', 'unnatural', 'wine;', 'patient.', 'prey', 'favourite,', 'comparative', 'grew', 'guilt,', 'Are', 'education', 'perused,', 'entreat', 'court.', 'chinks,', 'Oppressed', 'undertaking,', 'clock,', 'triumphant,', 'enterprise;', 'part', 'accent.', 'Arab,', 'within', 'flow;', 'coveted', 'withdrew.', 'proportionably.', 'madman', 'believed', 'unmolested,', 'said;', 'presently', 'perplexed,', 'divine', 'chill,', 'glowed', 'security,', 'opportunity', 'raven', 'mean', 'leave,', 'being,', 'bright', 'protecting', 'slight,', 'discovery,', 'stole', 'approach.', 'another', 'ameliorate', 'Arthur,', 'execution.', 'slowly,', 'world,', 'kind.”', 'deserving', 'madly', 'Know', 'untamed', 'live—swear', 'yellow', 'moment;', 'gazed', 'candle', 'redeem', 'powerful', 'hastened', 'inhabited.', 'welcome,', 'disowned?', 'Mannheim,', 'faults', 'now,', 'circle', 'magnificent', 'occasion.”', '“I', 'merchant’s', 'discontent', 'intensity', 'succeed,', 'Clerval', 'flowers,', 'borne', 'head,', 'demand,', 'linen', 'sensitive', 'hour’s', 'benefit,', 'conceited', 'shells', 'impression', 'deeper', 'encourage', 'thing.', 'windings', 'declining', 'equalled.', 'dread,', 'utterance', 'hearer', 'We', 'form.”', 'excursion', 'temporary', 'stretched', 'tainted', 'protraction', 'endeavours.', 'fulfilled!”', 'laughing', 'fluctuating', 'overlooks', 'sides', 'object', 'thrown,', 'sickening', 'hated', 'ensuing', 'rivers;', 'endless', 'indulging', 'piny', 'wretch!', 'receiving.”', 'indifferent,', 'firm;', 'mankind', 'destruction.”', 'electricity', 'at,', 'hours,', 'analysing', 'incessantly', 'merchant,', 'Once,', 'be?', 'flit', 'purchase', 'fact.', 'fangs', 'vexations', 'horizon.', 'contemplation.', 'fraud', 'befallen', 'satisfying', 'gratitude,', 'trial,', 'palpitation', 'clings', 'studied.', 'little,', 'nay,', 'emotions.', 'permission', 'fired', 'India,', 'straight', 'lover.', 'Amidst', 'produced.', 'modesty', 'herself,', 'impediment,', 'grand;', 'low,', 'rock,', 'man?', '“Of', 'gilded', 'repaired,', 'vain,', '12th,', 'upright', 'height,', 'career', 'revenge.', 'difficulty.', 'morrow;', 'ognor', 'world?', 'complain', 'continually', 'deposition', 'thee.', 'path;', 'out', 'dragged', 'included', 'sang', '“William,', 'brand;', 'exhaustion,', 'rawness', 'country', 'collected.', 'thinking', 'gold,', 'feeling,', 'supposed.', 'character,', 'lines,', 'acquainted,', '“Oh,', 'tone', 'augmenting', 'certainty,', 'sitting', 'identify', 'feet.', 'greater', 'stream,', 'it', 'appear;', 'berries,', 'Among', 'partiality.', 'neglected.”', 'view', 'fancy,', 'parched', 'dagger', 'improvements', 'degrees', 'patience.', 'preparatory', 'beloved,', 'envelop', 'patience', 'self-sacrifice', 'instead', 'laughter', 'akin', 'Before', 'dead', 'neck.', 'you—he', 'deposition,', 'sorrow;', 'misfortunes', 'feeble', 'metaphysical,', 'peaceably', 'century;', 'Turkey', 'floating', 'No,', 'servants.', 'gratifying', 'threatened', 'wail,', 'enjoy.”', 'book-keeping;', 'especial', 'sunshine.', 'impracticable;', 'marvellous,', 'succeeded.', 'medium', 'retrod', 'hazard.', 'faded', 'testimonies', 'because', 'involuntarily', 'emblem', 'But', 'murderer', 'discovered,', 'caves', 'argume ...
# Cleaned Words Length:  7649
# {'arveiron', 'infinity', 'childish', 'incoherent', 'limit', 'acquit', 'yield', 'attachment”', 'tinged', 'relative', 'dante', 'welfare', 'rise”', 'fifteen', 'inexorable', 'chapter', 'conformation', 'ceremony', 'homeward', 'detestation', 'profane', 'wondrously', 'void', 'letter', 'exchanged', 'sight', 'dried', 'enjoyments', 'retain', 'chances', 'o', 'regret', 'wrongfully', 'harden', 'fact', 'frowns', 'bad', 'labour', 'adversary', 'fairly', 'services', 'earnestness', 'them”', 'implores', 'waiting', 'loudness', 'reflection', 'wandering', 'proposed', 'kind', 'arisen', '_in', 'sir', '“d—n', 'indignant', 'wishes', 'presence', 'unnatural', 'prey', 'writings', 'comparative', 'grew', 'education', 'invitation', 'entreat', 'orientalists', 'part', 'within', 'coveted', 'madman', 'satan', 'believed', 'gibe', 'presently', 'divine', 'glowed', 'inquiries”', 'opportunity', 'raven', 'mean', 'bright', 'protecting', 'stole', 'another', 'rendezvous', 'atlantic', 'ameliorate', 'deserving', 'madly', 'untamed', 'live—swear', 'yellow', 'gazed', 'candle', 'redeem', 'powerful', 'hastened', 'faults', 'manon', 'circle', 'her”', 'magnificent', 'casement', 'merchant’s', 'discontent', 'intensity', 'borne', 'linen', 'gods', 'farmer', 'sensitive', 'hour’s', 'conceited', 'shells', 'impression', 'deeper', 'encourage', 'december', 'victor—one', 'irretrievable', 'windings', 'declining', 'utterance', 'hearer', 'parent', 'excursion', 'temporary', 'stretched', 'tainted', 'protraction', 'laughing', 'fluctuating', 'speaks', 'overlooks', 'sides', 'object', 'wish”', 'sickening', 'hated', 'ensuing', 'endless', 'indulging', 'separation', '18th', 'piny', 'mankind', 'electricity', 'flit', 'analysing', 'incessantly', 'own”', 'poems', 'purchase', 'fangs', 'wheel', 'vexations', 'me”', 'fraud', 'befallen', 'sea”', 'satisfying', 'murder”', 'palpitation', 'clings', 'permission', 'fired', 'biron', 'straight', 'christianity', 'modesty', 'gilded', 'italy—one', 'upright', 'career', 'ognor', 'complain', 'continually', 'deposition', 'difficulties', 'out', 'dragged', 'included', 'melbourne', 'sang', 'rawness', 'country', 'thinking', 'tone', 'augmenting', 'sitting', 'identify', 'greater', 'it', 'ingenuity', 'verdure', 'view', 'parched', '“alphonse', 'dagger', 'improvements', 'degrees', 'preparatory', 'envelop', 'patience', 'self-sacrifice', 'instead', 'laughter', 'akin', 'dead', 'you—he', 'feeble', 'misfortunes', 'peaceably', 'floating', 'gratifying', 'threatened', 'acquittal”', 'especial', 'mutability', 'medium', 'retrod', 'faded', 'testimonies', 'because', 'involuntarily', 'emblem', 'kennel', 'murderer', 'caves', 'drew', 'lived”', 'step', 'ballots', 'serenity', 'arrives', 'illustrious', 'treasure', 'deathlike', 'motion', 'listening', 'branches', 'philosopher’s', 'maintained', 'rw', 'kirwin', 'glimmer', 'threatening', 'gain', 'confused', 'lashes', 'confidential', 'facts', 'mildness', 'vivacity', 'retarded', 'manner', 'facile', 'wish', 'stayed', 'singularly', 'beaufort’s', 'perpendicularity', 'affectionately', 'virtue', 'ourselves—such', 'remove', 'sixth', 'delusion', 'unobserving', 'reverential', '“you', 'sting', 'theories', 'question', 'connection', 'other', 'raising', 'protestations', 'hereafter', 'endurance', 'reflections', 'empires_', 'happy', 'solely', 'college', 'contemplation', 'felt', 'prepossess', 'purchasing', 'clouds', 'continuing', 'cross', 'harem', 'moonlight', 'poverty', 'few', 'repressed', 'overhanging', 'mighty', 'carried', 'detect', 'unceasing', 'passes', 'cave', 'benefits', 'wiped', 'return', 'produces', 'unbending', 'complexion', 'commiserate', 'inclined', 'explore', 'woeful', 'pig', 'equally', 'foretaste', 'comprehend', 'unlawful', 'action', 'issuing', 'foster', 'knew', 'weeping', 'wretch', 'assizes', 'papa’', 'entirely', 'william', 'wear', 'flying', 'apt', 'since', 'obstinate', 'callous', 'inestimable', 'wounds', 'unspeakable', 'sick', 'float', 'people', 'faultiness', 'patches', 'resistless', 'tendency', 'morning', 'meanly', 'existed', 'self', 'inuring', 'moments', 'br ...
# 33
# 21

# %%
## Get top 10 words in the text
# Note: Use the Counter method to get the top 10 words
# Note: Use the most_common method to get the top 10 words
from collections import Counter

word_counts = Counter(words_cleaned)
top_10_words = word_counts.most_common(10)

# You will need to import Counter from collections to use the Counter method
# from collections import Counter 
# You might need to install collections using pip (in the terminal type: pip install collections)

# Print the top 10 words in the text
print("Top 10 Words in the text:")
for word, count in top_10_words:
    print(f"{word}: {count}")
# Out:
# Top 10 Words in the text:
# the: 4155
# and: 2958
# i: 2765
# of: 2639
# to: 2082
# my: 1751
# a: 1382
# in: 1122
# was: 1020
# that: 1004

# %%
#### Extra Credit ####
# Show me something interesting about the text that you found using python it can be anything
#here is the longest word in a text
longest_word = max(words_cleaned, key=len)

print (f"The longest word in the text is: '{longest_word}'")
# Out:
# The longest word in the text is: 'industrious—painstaking'
